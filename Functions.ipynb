# %% [markdown]
# To create a function in Python, you start the new block of code with word "def", then you add a function name with a prenthasis right behind that can take any inputs, and you finish the line with colon sign. In anoher line with a proper indentation you start to write your function.

# %%
def greeting():
    name = input("What is your name?: ")
    print("Hi " + name + "!")

# %% [markdown]
# For example: def greet(): print("Hi " + name) - and then you call it like greet(), code will ask you for your nameand that will give you output "Hi Jacek"

# %%
greeting()
# Out:
# What is your name?: Jacek
# Hi Jacek!
